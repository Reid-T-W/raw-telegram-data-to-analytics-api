# %%
# !pip install ultralytics

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
from ultralytics import YOLO

# Load a pretrained YOLO model (recommended for training)
model = YOLO("yolo11n.pt")

# Perform object detection on an image using the model
results = model("/content/id_2_photo_2022-09-05_09-57-09.jpg")

# Print results
r = results[0]

predicted_classes = [r.names[int(c)] for c in r.boxes.cls]
print(predicted_classes)
# Out:
# image 1/1 /content/id_2_photo_2022-09-05_09-57-09.jpg: 544x640 1 sports ball, 1 cake, 195.7ms
# Speed: 6.4ms preprocess, 195.7ms inference, 1.6ms postprocess per image at shape (1, 3, 544, 640)
# ['sports ball', 'cake']

# %%
from ultralytics import YOLO

# Load a pretrained YOLO model (recommended for training)
model = YOLO("yolo11n.pt")

# Perform object detection on an image using the model
results = model("/content/id_21_photo_2022-10-17_14-02-40.jpg")

# Print results
print(results.boxes)
# Out:
# image 1/1 /content/id_21_photo_2022-10-17_14-02-40.jpg: 640x640 (no detections), 243.6ms
# Speed: 7.9ms preprocess, 243.6ms inference, 1.5ms postprocess per image at shape (1, 3, 640, 640)
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /tmp/ipython-input-2122792049.py in <cell line: 0>()
#       8
#       9 # Print results
# ---> 10 print(results.boxes)
#
# AttributeError: 'list' object has no attribute 'boxes'

# %%
import os

data = []

dirs = [
  '/content/drive/MyDrive/10Academy/Week7/Data/TelegramDataLatest/CheMed123',
  '/content/drive/MyDrive/10Academy/Week7/Data/TelegramDataLatest/HakimApps_Guideline',
  '/content/drive/MyDrive/10Academy/Week7/Data/TelegramDataLatest/lobelia4cosmetics',
  '/content/drive/MyDrive/10Academy/Week7/Data/TelegramDataLatest/tenamereja',
  '/content/drive/MyDrive/10Academy/Week7/Data/TelegramDataLatest/tikvahpharma'
]

for dir in dirs:
  for entry in os.scandir(dir):
    inner_data = []
    entries = os.path.basename(entry.path).split('.')

    # Check is added to exclude csv files
    if entries[1] == 'jpg':
      # print(entry.path)
      results = model(entry.path)
      r = results[0]
      predicted_classes = [r.names[int(c)] for c in r.boxes.cls]

      # Concatenating predicted classes
      pred_classes=""
      for pred_class in predicted_classes:
        if pred_classes:
            pred_classes += ","
        pred_classes += pred_class

      inner_data.append(entry.path)
      inner_data.append(pred_classes)
      data.append(inner_data)

# Save to CSV
with open("yolo_detctions.csv", mode="a", newline="") as file:
    writer = csv.writer(file)
    writer.writerows(data)
# Out:
# image 1/1 /content/drive/MyDrive/10Academy/Week7/Data/TelegramDataLatest/CheMed123/id_2_photo_2022-09-05_09-57-09.jpg: 544x640 1 sports ball, 1 cake, 220.9ms
# Speed: 6.1ms preprocess, 220.9ms inference, 1.8ms postprocess per image at shape (1, 3, 544, 640)
#
# image 1/1 /content/drive/MyDrive/10Academy/Week7/Data/TelegramDataLatest/CheMed123/id_22_photo_2022-10-18_07-57-36.jpg: 544x640 2 cell phones, 197.3ms
# Speed: 5.6ms preprocess, 197.3ms inference, 1.5ms postprocess per image at shape (1, 3, 544, 640)
#
# image 1/1 /content/drive/MyDrive/10Academy/Week7/Data/TelegramDataLatest/CheMed123/id_38_photo_2022-11-29_07-43-06.jpg: 544x640 (no detections), 193.2ms
# Speed: 5.5ms preprocess, 193.2ms inference, 1.1ms postprocess per image at shape (1, 3, 544, 640)
#
# image 1/1 /content/drive/MyDrive/10Academy/Week7/Data/TelegramDataLatest/CheMed123/id_3_photo_2022-09-05_10-02-05.jpg: 640x640 (no detections), 231.3ms
# ...

# %%
import csv
